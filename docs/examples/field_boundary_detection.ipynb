# %% [markdown]
# # Field Boundary Detection with Instance Segmentation
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/field_boundary_detection.ipynb)
#
# This notebook demonstrates an end-to-end pipeline for detecting agricultural field boundaries using instance segmentation with Mask R-CNN. Accurate field boundary delineation is essential for precision agriculture, crop monitoring, subsidy verification, and land use planning.
#
# We use the [Fields of The World (FTW)](https://fieldsofthe.world/) benchmark dataset, which provides Sentinel-2 imagery (4 bands at 10 m resolution) paired with instance segmentation masks across 25 countries. Each chip provides two temporal windows (`window_a` and `window_b`) captured on different dates, so that seasonal vegetation differences can help delineate boundaries. We work with the **Luxembourg** subset, which is small enough for a tutorial while containing high-quality annotations.
#
# ## Install packages
#
# Uncomment the following line to install the required packages.

# %%
# %pip install geoai-py

# %% [markdown]
# ## Import libraries

# %%
import os
from pathlib import Path
import geopandas as gpd
import geoai

# %% [markdown]
# ## Download the FTW dataset
#
# The [Fields of The World (FTW)](https://fieldsofthe.world/) dataset contains 70,462 samples across 25 countries with Sentinel-2 imagery (4 bands: Red, Green, Blue, NIR at 10 m resolution) and instance segmentation masks. Each chip is 256×256 pixels.
#
# We download the **Luxembourg** subset, one of the smallest, making it ideal for a tutorial.

# %%
geoai.download_ftw(countries=["brazil"], output_dir="ftw_data")
# Out:
# Downloading brazil.zip:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# 'ftw_data'

# %% [markdown]
# ## Explore the dataset
#
# The FTW dataset includes a GeoParquet file with metadata and geometry for each chip, including the train/val/test split.

# %%
country_dir = os.path.join("ftw_data", "brazil")
chips_gdf = gpd.read_parquet(os.path.join(country_dir, "chips_brazil.parquet"))

print(f"Total chips: {len(chips_gdf)}")
print(f"\nSplit distribution:")
print(chips_gdf["split"].value_counts())
# Out:
# Total chips: 1607
#
# Split distribution:
# split
# train    1289
# test      188
# val       130
# Name: count, dtype: int64

# %% [markdown]
# Visualize the spatial distribution of training, validation, and test chips.

# %%
geoai.view_vector_interactive(chips_gdf, column="split")
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39dbd1f1fd2ac95e016a0ac1b9cb2e13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend split&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;split&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e41a1c&#x27;&gt;&lt;/span&gt;test&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#377eb8&#x27;&gt;&lt;/span&gt;train&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#4daf4a&#x27;&gt;&lt;/span&gt;val&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39dbd1f1fd2ac95e016a0ac1b9cb2e13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39dbd1f1fd2ac95e016a0ac1b9cb2e13 = L.map(
#                 &quot;map_39dbd1f1fd2ac95e016a0ac1b9cb2e13&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_39dbd1f1fd2ac95e016a0ac1b9cb2e13);
#
#
#
#
#
#             var tile_layer_35ac04d37dc3ffc3f4e7a41830f269fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35ac04d37dc3ffc3f4e7a41830f269fb.addTo(map_39dbd1f1fd2ac95e016a0ac1b9cb2e13);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_39dbd1f1fd2ac95e016a0ac1b9cb2e13);
#
#
#             map_39dbd1f1fd2ac95e016a0ac1b9cb2e13.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#         function geo_json_5a82073d4b7719be798812a0b33597f3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;1

# %% [markdown]
# Display sample image–mask pairs. Each mask uses unique integer IDs to distinguish individual field instances.

# %%
geoai.display_ftw_samples("ftw_data", country="brazil", num_samples=4)

# %% [markdown]
# ## Prepare training data
#
# GeoAI's Mask R-CNN pipeline expects `images/` and `labels/` directories with uint8 GeoTIFFs. The `prepare_ftw` function rescales Sentinel-2 reflectance (0–10,000) to uint8 (0–255), organizes files, and prepares test chips.

# %%
data = geoai.prepare_ftw("ftw_data", country="brazil")
data
# Out:
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000000-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000000-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000000-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000000-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000512-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000512-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000000512-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001024-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001024-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001024-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001024-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001536-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001536-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000001536-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002048-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002048-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002048-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002048-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002048-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000002560-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003072-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003072-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003072-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003072-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003072-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004608-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004608-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004608-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004608-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004608-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006656-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007168-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000007680-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008192-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008192-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008192-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008192-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008704-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008704-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000008704-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009216-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009216-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009216-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009728-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009728-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009728-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000009728-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010240-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010240-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010240-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010240-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010752-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010752-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010752-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010752-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000010752-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000011264-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000011264-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000011776-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000012800-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000012800-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000012800-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013312-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013312-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013312-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013312-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013824-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013824-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000013824-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000000512-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001024-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000001536-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002048-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004096-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000004608-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005120-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000006144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000015360.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008704-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# ...
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000012800-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000012800-0000006656.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000012800-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000000000.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005120-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000005632-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000006144-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000002560-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003072-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000012288.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000012800.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000003584-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000005632-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006144-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000006656-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007168-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000007680-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000008192-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000008192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013312-0000008704.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013824-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013824-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013824-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000013824-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014336-0000003072.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014336-0000003584.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014336-0000004096.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014336-0000007680.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014848-0000000512.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014848-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014848-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014848-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000014848-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000015360-0000001024.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000015872-0000007168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000015872-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000015872-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016384-0000016896.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016384-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016384-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016896-0000016896.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016896-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000016896-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000017408-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000017408-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000017920-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000017920-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000017920-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018432-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018432-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018432-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018944-0000009216.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018944-0000009728.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000018944-0000010240.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019456-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019456-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019456-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019456-0000013312.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019968-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000019968-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000020992-0000018432.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000020992-0000018944.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000021504-0000018432.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000025600-0000013824.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000025600-0000014336.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000025600-0000014848.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027136-0000016896.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027136-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027136-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027648-0000016896.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027648-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000027648-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000028160-0000016896.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000028160-0000017408.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g2_0000028160-0000017920.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000000512-0000005632.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000001024-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005120-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005120-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005120-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005632-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005632-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000005632-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000006144-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000006144-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g3_0000006144-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000000512-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000000512-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000002560-0000004608.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000002560-0000005120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007168-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007680-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007680-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007680-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007680-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000007680-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000008192-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000008192-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000008192-0000010752.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000008192-0000011264.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g4_0000008192-0000011776.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000003584-0000002560.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000001536.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in g1_0000004096-0000002048.tif: BLOCKXSIZE can only be used with TILED=YES
# {'images_dir': 'field_boundaries/images',
#  'labels_dir': 'field_boundaries/labels',
#  'test_dir': 'field_boundaries/test',
#  'num_train': 1419,
#  'num_test': 5}

# %% [markdown]
# Verify that the prepared tiles look correct.

# %%
geoai.display_training_tiles(
    output_dir="field_boundaries",
    num_tiles=4,
    figsize=(12, 6),
    cmap="tab20",
)
# Out:
# (<Figure size 1200x600 with 8 Axes>,
#  array([[<Axes: title={'center': 'Image 1'}>,
#          <Axes: title={'center': 'Image 2'}>,
#          <Axes: title={'center': 'Image 3'}>,
#          <Axes: title={'center': 'Image 4'}>],
#         [<Axes: title={'center': 'Mask 1'}>,
#          <Axes: title={'center': 'Mask 2'}>,
#          <Axes: title={'center': 'Mask 3'}>,
#          <Axes: title={'center': 'Mask 4'}>]], dtype=object))

# %% [markdown]
# ## Train instance segmentation model
#
# We train a Mask R-CNN model with a ResNet-50 + FPN backbone.
#
# Key parameters:
# - **`num_classes=2`** — Background (0) and field (1).
# - **`num_channels=4`** — Sentinel-2 bands (R, G, B, NIR). NIR helps distinguish vegetation boundaries.
# - **`instance_labels=True`** — The FTW masks already encode unique instance IDs, so geoai should use them directly instead of running connected-component labeling.
# - **`num_epochs=20`** — Sufficient for demonstration; increase to 50–100 for production.
# - **`val_split=0.2`** — Reserves 20% of chips for validation.

# %%
geoai.train_instance_segmentation_model(
    images_dir=data["images_dir"],
    labels_dir=data["labels_dir"],
    output_dir="field_boundaries/models",
    num_classes=2,
    num_channels=4,
    batch_size=4,
    num_epochs=20,
    learning_rate=0.005,
    val_split=0.2,
    instance_labels=True,
    visualize=True,
    verbose=True,
)
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 170M/170M [00:00<00:00, 302MB/s]

# %% [markdown]
# ## Training performance
#
# Examine the training and validation loss curves to assess model convergence.

# %%
geoai.plot_performance_metrics(
    history_path="field_boundaries/models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ## Run inference
#
# Apply the trained model to a test image using sliding window inference with window size 256 and overlap 128.

# %%
test_images = sorted(Path(data["test_dir"]).glob("*.tif"))
test_image_path = str(test_images[0])
masks_path = "field_boundary_prediction.tif"
model_path = "field_boundaries/models/best_model.pth"

result = geoai.instance_segmentation(
    input_path=test_image_path,
    output_path=masks_path,
    model_path=model_path,
    num_classes=2,
    num_channels=4,
    window_size=256,
    overlap=128,
    confidence_threshold=0.5,
    batch_size=4,
    vectorize=True,
    class_names=["background", "building"],
)
result

# %% [markdown]
# ## Visualize raw predictions
#
# Each color represents a distinct field instance detected by the model.

# %%
geoai.view_raster(
    result["instance"],
    nodata=0,
    cmap="tab20",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %%
geoai.view_raster(
    result["class_label"],
    nodata=0,
    cmap="binary",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %%
geoai.view_raster(
    result["score"], nodata=0, basemap=test_image_path, backend="ipyleaflet"
)

# %%
geoai.view_vector_interactive(result["vector"], tiles=test_image_path, column="score")

# %% [markdown]
# ## Clean instance mask
#
# Remove small spurious detections and fill holes between adjacent instances using `clean_instance_mask`. This is designed specifically for instance segmentation outputs (unlike `clean_raster`, which is for semantic/classification masks).

# %%
cleaned_masks_path = "field_boundary_prediction_cleaned.tif"
geoai.clean_instance_mask(
    result["instance"], cleaned_masks_path, min_area=100, max_hole_area=100
)

# %%
geoai.view_raster(
    cleaned_masks_path,
    nodata=0,
    cmap="tab20",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %% [markdown]
# ## Vectorize predictions
#
# Convert the cleaned raster mask to vector polygons for spatial analysis.

# %%
output_vector_path = "field_boundary_prediction.geojson"
gdf = geoai.raster_to_vector(cleaned_masks_path, output_vector_path)

# %% [markdown]
# ## Compare predictions with imagery
#
# Use a split map to visually compare the detected field boundaries against the original Sentinel-2 imagery.

# %%
geoai.create_split_map(
    left_layer=gdf,
    right_layer=test_image_path,
    left_args={"style": {"color": "red", "fillOpacity": 0.2}},
    basemap=test_image_path,
)

# %% [markdown]
# ## Geometric properties
#
# Calculate geometric properties for each detected field:
#
# | Property | Description |
# |----------|-------------|
# | **Area** | Field size in hectares — critical for yield estimation and subsidy programs |
# | **Perimeter** | Boundary length — useful for fencing cost estimation |
# | **Elongation** | Major/minor axis ratio — distinguishes strip fields from compact parcels |
# | **Solidity** | Area/convex hull area ratio — measures boundary irregularity |
# | **Extent** | Area/bounding box area ratio — indicates how rectangular a field is |

# %%
gdf_props = geoai.add_geometric_properties(gdf, area_unit="ha", length_unit="m")
gdf_props.head()

# %%
gdf_props.describe()

# %% [markdown]
# ## Visualize fields by property

# %%
geoai.view_vector_interactive(gdf_props, column="area_ha", tiles=test_image_path)

# %%
geoai.view_vector_interactive(gdf_props, column="elongation", tiles=test_image_path)

# %% [markdown]
# ## Batch processing
#
# Process all test images at once.

# %%
geoai.instance_segmentation_batch(
    input_dir=data["test_dir"],
    output_dir="field_boundaries/predictions",
    model_path=model_path,
    num_classes=2,
    num_channels=4,
    window_size=256,
    overlap=128,
    confidence_threshold=0.5,
    batch_size=4,
)

# %% [markdown]
# ## Summary
#
# This notebook demonstrated a complete field boundary detection pipeline:
#
# 1. **Data acquisition** — Downloaded the FTW Luxembourg dataset with `geoai.download_ftw()`.
# 2. **Data preparation** — Rescaled Sentinel-2 reflectance to uint8 with `geoai.prepare_ftw()`.
# 3. **Training** — Trained Mask R-CNN with `instance_labels=True` to preserve field identity.
# 4. **Inference** — Applied sliding window inference to test imagery.
# 5. **Post-processing** — Cleaned instance masks with `clean_instance_mask()`, then vectorized.
# 6. **Analysis** — Computed geometric properties (area, perimeter, elongation, solidity).
#
# ### Tips for improving results
#
# - **More training data**: Download additional FTW countries with `geoai.download_ftw(countries=["france", "austria"])`.
# - **Both temporal windows**: Use `window="window_b"` in `prepare_ftw()` for a different season, or stack both for 8-band input.
# - **Longer training**: Increase `num_epochs` to 50–100.
# - **Confidence tuning**: Lower `confidence_threshold` (e.g., 0.3) to detect more fields at the cost of more false positives.
# - **Post-processing**: Adjust `min_area` and `max_hole_area` in `clean_instance_mask()` to match your target field sizes.
